# %%
#Carga de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf

# %%
#Carga de data frame que usaremos BUENOS AIRES LISTINGS
data= pd.read_csv("listingsba.csv")
data
# Out:
#              id                            listing_url       scrape_id  \
# 0         11508     https://www.airbnb.com/rooms/11508  20220922013624
# 1        118877    https://www.airbnb.com/rooms/118877  20220922013624
# 2         14222     https://www.airbnb.com/rooms/14222  20220922013624
# 3        120874    https://www.airbnb.com/rooms/120874  20220922013624
# 4        122907    https://www.airbnb.com/rooms/122907  20220922013624
# ...         ...                                    ...             ...
# 17942  32279620  https://www.airbnb.com/rooms/32279620  20220922013624
# 17943  27460266  https://www.airbnb.com/rooms/27460266  20220922013624
# 17944  46217105  https://www.airbnb.com/rooms/46217105  20220922013624
# 17945  31262931  https://www.airbnb.com/rooms/31262931  20220922013624
# 17946  32204376  https://www.airbnb.com/rooms/32204376  20220922013624
#
#       last_scraped       source  \
# 0       2022-09-22  city scrape
# 1       2022-09-22  city scrape
# ...

# %%
#No todas las columnas de la base de datos original son de utilidad de nuestro análisis 
#Por lo que se eliminarán algunas.
df0=data.drop(['scrape_id', 'last_scraped', 'source','neighborhood_overview', 'picture_url', 'host_url','host_name', 'host_since', 'host_location','host_about', 'host_is_superhost', 'host_thumbnail_url','minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights','calendar_updated', 'availability_30', 'availability_90','availability_365', 'review_scores_rating', 'review_scores_accuracy','review_scores_checkin', 'review_scores_communication', 'review_scores_value','listing_url','amenities'], axis=1)
df=df0.drop(['host_picture_url', 'host_neighbourhood', 'host_listings_count','host_total_listings_count', 'host_has_profile_pic', 'host_identity_verified','neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'bathrooms_text','maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_60','calendar_last_scraped', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'review_scores_cleanliness','review_scores_location', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms'], axis=1)
df
# Out:
#              id                                               name  \
# 0         11508                 Amazing Luxurious Apt-Palermo Soho
# 1        118877                  Entire Studio/apt in Buenos Aires
# 2         14222       RELAX IN HAPPY HOUSE - PALERMO, BUENOS AIRES
# 3        120874           Great apt 1 Bedroom - 1.5 Bath /Recoleta
# 4        122907                Spotless entire apt. Ideal location
# ...         ...                                                ...
# 17942  32279620                        Lumiere Place Puerto Madero
# 17943  27460266  ••WELCOME! New Modern Suite Puerto Madero |CasaBA
# 17944  46217105    ☆PUERTO MADERO LUXURIOUS APARTMENT ☆ CasaBAires
# 17945  31262931           Puerto Madero Elegant Suite | CasaBAires
# 17946  32204376     Apartamento Puerto Madero 2 ambientes amplios!
#
#                                              description    host_id  \
# 0      <b>The space</b><br />LUXURIOUS NEW APT: 1 BDR...      42762
# ...

# %%
#Identificación de valores nulos
null=df.isnull(). sum()
null
# Out:
# id                          0
# name                        3
# description               512
# host_id                     0
# host_response_time       2420
# host_response_rate       2420
# host_acceptance_rate     2013
# host_verifications          0
# neighbourhood            7521
# latitude                    0
# longitude                   0
# property_type               0
# room_type                   0
# accommodates                0
# bathrooms               17947
# bedrooms                 2516
# beds                      245
# price                       0
# minimum_nights              0
# maximum_nights              0
# has_availability            0
# number_of_reviews           0
# first_review             3807
# last_review              3807
# license                 17584
# reviews_per_month        3807
# dtype: int64

# %%
#Sustitución con diferentes métodos 

#Para el nombre de los propietarios, se colocará "Nombre anonimo"
df["name"]= df["name"].fillna('Desconocido')

#Dentro de la descripción se colocará "Se desconoce la descripción del lugar"
df["description"]= df["description"].fillna('Se desconoce la descripción del lugar')

#El tiempo que tarda en responder el host quedará como "El anfitrión responderá en unos días"
df["host_response_time"]= df["host_response_time"].fillna('El anfitrión responderá en unos días')

#host response rate
df["host_response_rate"]= df["host_response_rate"].fillna(method='ffill')

#host acceotance rate
df["host_acceptance_rate"]= df["host_acceptance_rate"].fillna(method='ffill')
df["host_acceptance_rate"]= df["host_acceptance_rate"].fillna(method='bfill')

#neighbouthood
df["neighbourhood"]= df["neighbourhood"].fillna(method='ffill')

#bathrooms - se colocó 1, pues es el minimo de baños que podría tener
df['bathrooms']=df['bathrooms'].fillna(1)

#bedrooms - se colocó 1 
df['bedrooms']=df['bedrooms'].fillna(1)

#bedrooms
df['beds']=df['beds'].fillna(1)

#first_review
df["first_review"]=df["first_review"].fillna('00/00/0000')

#last_review
df["last_review"]=df["last_review"].fillna('00/00/0000')

#license
df["license"]= df["license"].fillna('Información no disponible')

#reviews_per_month 
df['reviews_per_month']=df['reviews_per_month'].fillna(0)

# %%
#Identificación de valores nulos
null=df.isnull(). sum()
null
# Out:
# id                      0
# name                    0
# description             0
# host_id                 0
# host_response_time      0
# host_response_rate      0
# host_acceptance_rate    0
# host_verifications      0
# neighbourhood           0
# latitude                0
# longitude               0
# property_type           0
# room_type               0
# accommodates            0
# bathrooms               0
# bedrooms                0
# beds                    0
# price                   0
# minimum_nights          0
# maximum_nights          0
# has_availability        0
# number_of_reviews       0
# first_review            0
# last_review             0
# license                 0
# reviews_per_month       0
# dtype: int64

# %%
#Guardar base de datos limpia en un nuevo .csv
df.to_csv("buenosAires_clean.csv")
